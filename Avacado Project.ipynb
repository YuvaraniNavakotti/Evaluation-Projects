# %% [markdown]
# # Avacado Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading the data set

# %%
df=pd.read_csv("C:/Users/yn/Desktop/Yuvi/DataTrained/EvaluationProjects/avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# we have 18249 rows and 14 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# We have 3 object type features

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# Observations:
# 1. The average price of an avocado is 1.40
# 2. Seems like we have outliers in 4046,4225,4770,Total Bags,Small Bags,Large Bags,XLarge Bags

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# We have 2 type of Avocados, Oraganic and Conventional and in our dataset we have almost equal amount of avocados given in both type

# %%
print(df['region'].value_counts())
print(len(df['region'].unique()))
# Out:
# Seattle                338
# Philadelphia           338
# SouthCentral           338
# Tampa                  338
# Boston                 338
# Midsouth               338
# BuffaloRochester       338
# Orlando                338
# Louisville             338
# Nashville              338
# Columbus               338
# DallasFtWorth          338
# NorthernNewEngland     338
# NewOrleansMobile       338
# RichmondNorfolk        338
# HartfordSpringfield    338
# Southeast              338
# Charlotte              338
# Roanoke                338
# LasVegas               338
# Chicago                338
# StLouis                338
# Detroit                338
# SanDiego               338
# Houston                338
# Syracuse               338
# SouthCarolina          338
# LosAngeles             338
# SanFrancisco           338
# GreatLakes             338
# Boise                  338
# California             338
# BaltimoreWashington    338
# GrandRapids            338
# ...

# %% [markdown]
# We have 54 regions in our dataset and all regions are having almost equal amount of avocado selling count.

# %% [markdown]
# ##### Lets check for missing values

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# We do not have any missing data in the data set

# %% [markdown]
# Lets convert date column to day and month and year. We already have year field given in the data. So will spilit the date into day and month.

# %%
df['date']=[x.split('-')[2] for x in df['Date']]
df['date']=df['date'].astype(int)
df['month']=[x.split('-')[1] for x in df['Date']]
df['month']=df['month'].astype(int)

# %% [markdown]
# As we splitted the date into day, month, lets drop date column.

# %%
df.drop(['Unnamed: 0','Date'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
#  12  date          18249 non-null  int32
#  13  month         18249 non-null  int32
# dtypes: float64(9), int32(2), int64(1), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Data Visualization

# %%
df.hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>],
#        [<AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>],
#        [<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'date'}>,
#         <AxesSubplot:title={'center':'month'}>]], dtype=object)

# %% [markdown]
# ##### Univariate Analysis

# %% [markdown]
# Lets split categorical and continous features first.

# %%
categorical_features=[]
continous_features=[]
for col in df.columns:
    if df[col].dtype=='object':
        categorical_features.append(col)
    else:
        continous_features.append(col)

# %% [markdown]
# Let's check data is normally distributed or not

# %%
for col in continous_features:
    sns.distplot(df[col])
    plt.figure(figsize=(4,4))
    plt.show()

# %% [markdown]
# Observations from above distribution plot:
# 1. Our regression target variable AveragePrice is noramally distributed.
# 2. All other continous data are not normally distributed.

# %% [markdown]
# Lets add date, month and year as categorical features list.

# %%
date_features=['date','month','year']
for i in date_features:
    continous_features.remove(i)
    categorical_features.append(i)

# %% [markdown]
# ##### Lets check how data scattered between the features and the target variable.

# %%
for col in continous_features:
    sns.scatterplot(df[col],df['AveragePrice'])
    plt.figure(figsize=(4,4))
    plt.show()

# %% [markdown]
# We could not see much trend from the above plot, let's plot bivariate plots and see.

# %% [markdown]
# ##### Bivariate Analysis

# %%
sns.stripplot(df['type'],df['XLarge Bags'])
plt.show()

# %% [markdown]
# We have very less organic avocados in the Xlarge bags

# %%
sns.stripplot(df['type'],df['Large Bags'])
plt.show()

# %% [markdown]
# We can see few organic avocados in large bags and more conventional avocados.

# %%
sns.stripplot(df['type'],df['Small Bags'])
plt.show()

# %% [markdown]
# Small bags having little more organic avacodas comparing to large and Xlarge bags.

# %%
plt.figure(figsize=(12,10))
sns.countplot(df['region'],hue=df['type'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This plot shows that all the regions are having equal amount of organic and conventional type avocados.

# %%
plt.figure(figsize=(6,4))
sns.barplot(df['type'],df['AveragePrice'])
plt.show()

# %% [markdown]
# The above plot clearly shows that the average price of Organic avocados are higher than conventional avacados.

# %%
plt.figure(figsize=(6,4))
sns.barplot(df['type'],df['Total Volume'])
plt.show()

# %% [markdown]
# Conventional avocados are contributing more to the Total volume than the organic type avocadas.

# %%
plt.figure(figsize=(6,4))
sns.barplot(df['type'],df['4225'])
plt.show()

# %% [markdown]
# We can see few organic avocados with PLU 4225 code and more conventional avocados with PLU 4225.

# %%
plt.figure(figsize=(6,4))
sns.barplot(df['type'],df['4770'])
plt.show()

# %% [markdown]
# There is no/very very few Organic type avocados with PLU code 4770

# %%
plt.figure(figsize=(6,4))
sns.barplot(df['type'],df['4046'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(df['year'],hue=df['type'])
plt.show()

# %% [markdown]
# 1. In the year of 2017, the sell count of avacados are more than other years.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df['month'],df['Total Volume'],hue=df['year'])
plt.show()

# %% [markdown]
# We have more number of selling count in the month of 2.

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['Total Volume'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between total volume and avarage price of avacado against the type of avacado')
plt.show()

# %% [markdown]
#  In the above plot we can see distribution of Average price and total volume against the type of avacado.From this plot we can see that total volume of organic type avacado are 0. We have more conventional type avacados here. The average highest price of conventional type avacado is 2.25.
#  Also we could observe that majority of the data points contains the total volume of avacados below 1,00,00,000.

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['4046'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados with PLU code 4046 and avarage price against the type of avacado')
plt.show()

# %% [markdown]
# From the above plot we can see that we have more conventional type organic with PLU code 4046 and no or very very few organic type avacados.Here also we can see the maximum avg price of PLU code 4046 avacado is 2.25.Also we could observe that majority of data points has the total volume of sold avacados(PLU 4046) count below to 50,00,000

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['4225'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados with PLU code 4225 and avarage price against the type of avacado')
plt.show()

# %% [markdown]
# From the above plot we can see that we have more conventional type organic with PLU code 4225 and no or very very few organic type avacados.Here also we can see the maximum avg price of PLU code 4046 avacado is 2.25 and avg price of organic avacados are higher than conventional avacados.Also we could observe that majority of data points has the total volume of sold avacados(PLU 4225) count below to 50,00,000

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['4770'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados with PLU code 4770 and avarage price against the type of avacado')
plt.show()

# %% [markdown]
# From the above plot we can see that we have more conventional type organic with PLU code 4770 and no or very very few organic type avacados.Here also we can see the maximum avg price of PLU code 4046 avacado is 2.25 and avg price of organic avacados are higher than conventional avacados.Also we could observe that majority of data points has the total volume of sold avacados(PLU 4770) count below to 50,00,000

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['Total Bags'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados with Total Bags and avarage price against the type of avacado')
plt.show()

# %% [markdown]
# From the above plot we can clearly see that count of organic avacados are less and its avarage price is higher than conventional avacados.

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['Small Bags'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados with Small Bags and avarage price against the type of avacado')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['Large Bags'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados Large Bags and avarage price against the type of avacado')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(df['XLarge Bags'],df['AveragePrice'],hue=df['type'])
plt.title('Comparison between avacados with XLarge Bags and avarage price against the type of avacado')
plt.show()

# %% [markdown]
# This plot shows that we do not have/we have very very few organic type avacados in Xlarge bags.

# %% [markdown]
# 1. From the above plot we can observe that we have total no.of bags count more in total US and West followed by South Central and California.
# 2. Also we have more organic type avacado bags in total US and West and followed by NorthWest and GreatLakes.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df['4046'],df['4225'],hue=df['type'])
plt.show()

# %% [markdown]
# 1. The above plot shows that 4046 and 4225 are linearly related to each other.
# 2. When the sell of 4046 PLU avacados increase, sell count of 4225 PLU type of avacados also increasing.
# 3. We could see very less organic type avacados in the both PLU code 4046 and 4225.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df['4046'],df['4770'],hue=df['type'])
plt.show()

# %% [markdown]
# 1. The above plot shows that 4046 and 4770 are linearly related to each other.
# 2. When the sell count of 4046 PLU avacados increase, sell count of 4770 PLU avacados also increasing.
# 3. We could see very less organic type avacados in the both PLU code 4046 and 4770.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df['4225'],df['4770'],hue=df['type'])
plt.show()

# %% [markdown]
# 1. The above plot shows that 4770 and 4225 are linearly related to each other.
# 2. When the sell count of 4770 PLU avacados increase, sell count of 4225 PLU avacados also increasing.
# 3. We could see very less organic type avacados in the both PLU code 4770 and 4225.

# %%
plt.figure(figsize=(18,12))
sns.pointplot(y=df['AveragePrice'],x=df['region'],hue=df['year'],join=False)
plt.xticks(rotation=90,fontsize=12)
plt.xticks(fontsize=12)
plt.xlabel('Region',fontsize=16)
plt.ylabel('AveragePrice',fontsize=16)
plt.title("Yearly Average Price in Each Region",{'fontsize':20})
plt.show()

# %% [markdown]
# From the above plot we can see that average price of an avocado is very high in SanFrancisco region in the year of 2017 and followed by HarrisburgScranton.
# Also we have very low average price in Houston in the year of 2018.

# %% [markdown]
# From all the above observations we can conclude below points.
# 1. In the year of 2017, the total selling volume is higher than other years.
# 2. The Average price of Organic type avacados are higher than conventional type avacados.
# 3. The selling amount in all the regions are more or less same. We could not see major difference in any of the region.
# 4. The total selling count of Organic and conventional avacados are almost equal in all the given years.
# 5. In all the PLU coded Avocadas we have very few organic type avocadas and more conventional avocados.
# 6. The average price of an avocado is high in SanFrancisco region than other regions.

# %% [markdown]
# #### Transforming the object type features to numbers

# %%
obj_features=['type','region']
from sklearn.preprocessing import LabelEncoder
for i in obj_features:
    df[i]=LabelEncoder().fit_transform(df[i])
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  date  month
# 0     8603.62       93.25          0.0     0  2015       0    27     12
# 1     9408.07       97.49          0.0     0  2015       0    20     12
# 2     8042.21      103.14          0.0     0  2015       0    13     12
# 3     5677.40      133.76          0.0     0  2015       0     6     12
# 4     5986.26      197.69          0.0     0  2015       0    29     11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  int32
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  int32
#  12  date          18249 non-null  int32
#  13  month         18249 non-null  int32
# dtypes: float64(9), int32(4), int64(1)
# memory usage: 1.7 MB

# %%
df.type.value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %%
df.region.value_counts()
# Out:
# 0     338
# 27    338
# 39    338
# 8     338
# 24    338
# 40    338
# 9     338
# 25    338
# 41    338
# 10    338
# 26    338
# 42    338
# 11    338
# 43    338
# 16    338
# 12    338
# 28    338
# 44    338
# 13    338
# 29    338
# 45    338
# 14    338
# 30    338
# 46    338
# 15    338
# 31    338
# 23    338
# 7     338
# 38    338
# 22    338
# 32    338
# 48    338
# 1     338
# 17    338
# 33    338
# 49    338
# 2     338
# 18    338
# 34    338
# 50    338
# 3     338
# 19    338
# 35    338
# 51    338
# 4     338
# 20    338
# 36    338
# 52    338
# 5     338
# 21    338
# 37    338
# 6     338
# 47    338
# 53    335
# Name: region, dtype: int64

# %% [markdown]
# ### Chekcing multi colinearity

# %%
plt.figure(figsize=(18,16))
sns.heatmap(df.corr().abs(),annot=True)
plt.show()

# %% [markdown]
# Observations from above heat map:
# 1. Total Bags are highly correlated with Small bags.
# 2. 4046 is 98% correlated with Total volume.
# 3. 4225 is 97% correlated with Total Volume.
# 4. Small bags are 97% correlated with Total Volume.
# 5. Total bags and Total volume are 96% correlated to each other.
# 6. We could see more features are correlated with each other more than 90%.

# %% [markdown]
# ##### Lets plot correlation of features with target(AveragePrice)

# %%
plt.figure(figsize=(12,8))
df.corr()['AveragePrice'].sort_values().drop(['AveragePrice']).plot(kind='bar')
plt.xlabel('Feature variables')
plt.ylabel('AveragePrice')
plt.xticks(rotation=90)
plt.title('Correlation between features and AveragePrice')
plt.show()

# %% [markdown]
# We could see region is having very low correlation with target variable AveragePrice.

# %% [markdown]
# ### Removing Outliers

# %%
for col in df.columns:
    sns.boxplot(df[col])
    plt.show()

# %% [markdown]
# ##### Lets remove outliers using Zscore

# %%
from scipy.stats import zscore

# %%
outlier_features=['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']

# %%
score=zscore(df[outlier_features])
filters=(score<3).all(axis=1)
new_df=df[filters]
print(df.shape,new_df.shape)
# Out:
# (18249, 14) (17782, 14)

# %% [markdown]
# We have removed 467 data points using Zscore.

# %% [markdown]
# Data loss:

# %%
data_loss=((df.shape[0]-new_df.shape[0])/df.shape[0])*100
data_loss
# Out:
# 2.55904433119623

# %% [markdown]
# We lost 2.5% of data by removing outliers.

# %% [markdown]
# ### Removing Data Skewness

# %%
new_df.skew().sort_values()
# Out:
# type           -0.052210
# region          0.005773
# date            0.011251
# month           0.098217
# year            0.220792
# AveragePrice    0.560969
# Total Volume    3.782060
# Total Bags      4.082103
# Small Bags      4.238647
# 4225            4.472729
# 4046            4.928850
# Large Bags      5.072468
# 4770            5.137120
# XLarge Bags     6.159391
# dtype: float64

# %% [markdown]
# We could see skewness in the features Total Volume,Total Bags,Small Bags,4225,4046,Large Bags,4770,Xlarge Bags

# %% [markdown]
# ##### Lets remove the skewness by appylying transformation to the data.

# %%
from sklearn.preprocessing import PowerTransformer

# %%
skewed_features=['Total Volume','Total Bags','Small Bags','4225','4046','Large Bags','4770','XLarge Bags']

# %%
new_df[skewed_features]=PowerTransformer().fit_transform(new_df[skewed_features])
print(new_df.skew().sort_values())
# Out:
# Large Bags     -0.110061
# type           -0.052210
# 4225           -0.043246
# 4046           -0.038259
# Small Bags     -0.024657
# Total Bags     -0.021531
# Total Volume   -0.006809
# region          0.005773
# date            0.011251
# 4770            0.028015
# month           0.098217
# year            0.220792
# AveragePrice    0.560969
# XLarge Bags     0.860603
# dtype: float64

# %%
new_df['XLarge Bags']=np.log(new_df)

# %%
print(new_df.skew().sort_values())
# Out:
# XLarge Bags    -0.211177
# Large Bags     -0.110061
# type           -0.052210
# 4225           -0.043246
# 4046           -0.038259
# Small Bags     -0.024657
# Total Bags     -0.021531
# Total Volume   -0.006809
# region          0.005773
# date            0.011251
# 4770            0.028015
# month           0.098217
# year            0.220792
# AveragePrice    0.560969
# dtype: float64

# %% [markdown]
# #### Removing multicolinearity using VIF scores

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X=new_df.drop(['AveragePrice'],axis=1)
y=new_df['AveragePrice']

# %%
vif = pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif['Features'] = X.columns
vif.sort_values(by='VIF values',ascending=False)
# Out:
#     VIF values      Features
# 0    53.023383  Total Volume
# 4    34.265884    Total Bags
# 5    17.333491    Small Bags
# 9    13.490954          year
# 2    11.907633          4225
# 8     7.739889          type
# 1     7.027781          4046
# 7     4.435863   XLarge Bags
# 12    4.278669         month
# 10    4.218119        region
# 11    4.202604          date
# 3     3.757857          4770
# 6     3.435234    Large Bags

# %%
X.drop(['Total Volume'],axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif['Features'] = X.columns
vif.sort_values(by='VIF values',ascending=False)
# Out:
#     VIF values     Features
# 3    25.507447   Total Bags
# 4    17.323189   Small Bags
# 8    13.012477         year
# 7     7.543034         type
# 1     4.390562         4225
# 6     4.319362  XLarge Bags
# 11    4.278633        month
# 10    4.202567         date
# 9     4.200409       region
# 2     3.742892         4770
# 0     3.739737         4046
# 5     3.383412   Large Bags

# %%
X.drop(['Total Bags'],axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif['Features'] = X.columns
vif.sort_values(by='VIF values',ascending=False)
# Out:
#     VIF values     Features
# 7    12.996475         year
# 6     7.515576         type
# 10    4.268542        month
# 9     4.202549         date
# 8     4.198853       region
# 1     4.196317         4225
# 5     4.071704  XLarge Bags
# 0     3.739736         4046
# 2     3.738325         4770
# 3     3.510596   Small Bags
# 4     1.849209   Large Bags

# %%
X.drop(['year'],axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif['Features'] = X.columns
vif.sort_values(by='VIF values',ascending=False)
# Out:
#    VIF values     Features
# 6    6.240416         type
# 1    4.142910         4225
# 5    4.059518  XLarge Bags
# 0    3.736583         4046
# 2    3.618625         4770
# 7    3.516909       region
# 3    3.496259   Small Bags
# 9    3.310885        month
# 8    3.192567         date
# 4    1.848307   Large Bags

# %%
X.drop(['Small Bags'],axis=1,inplace=True)

# %%
vif = pd.DataFrame()
vif['VIF values']= [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif['Features'] = X.columns
vif.sort_values(by='VIF values',ascending=False)
# Out:
#    VIF values     Features
# 5    6.194971         type
# 4    4.059516  XLarge Bags
# 1    3.836160         4225
# 6    3.516757       region
# 2    3.491939         4770
# 0    3.355507         4046
# 8    3.301557        month
# 7    3.187350         date
# 3    1.842218   Large Bags

# %%
print(X.shape,y.shape)
# Out:
# (17782, 9) (17782,)

# %% [markdown]
# ### Model Building

# %% [markdown]
# ### Predicting Average Price - Regression Problem

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %% [markdown]
# Scaling the feature variable using standard scalar.

# %%
X_sc=StandardScaler().fit_transform(X)

# %% [markdown]
# ##### Finding best Randomstate

# %%
m_acc=0
b_rs=0
for i in range(1,200):
    lr=LinearRegression()
    X_train,X_test,y_train,y_test=train_test_split(X_sc,y,test_size=0.25,random_state=i)
    lr.fit(X_train,y_train)
    y_pred=lr.predict(X_test)
    acc=r2_score(y_test,y_pred)
    if(acc>m_acc):
        m_acc=acc
        b_rs=i
print("Best Accuracy: ",m_acc,"Best RS: ",b_rs)
# Out:
# Best Accuracy:  0.9681448878466101 Best RS:  55

# %% [markdown]
# Splitting the train test data set using best random state found.

# %%
X_train,X_test,y_train,y_test=train_test_split(X_sc,y,test_size=0.25,random_state=55)

# %%
lr=LinearRegression()
rf_reg=RandomForestRegressor()
knn_reg=KNeighborsRegressor()
ls=Lasso()
rd_reg=Ridge()
svm_reg=SVR()

models=[lr,rf_reg,knn_reg,ls,rd_reg,svm_reg]

# %% [markdown]
# #### Building base models - Model selection

# %%
for m in models:
    m.fit(X_train,y_train)
    y_pred=m.predict(X_test)
    print("Metrics for ",m)
    print("Trian Accuracy: ",m.score(X_train,y_train))
    print("Test Accuracy: ",r2_score(y_test,y_pred))
    print("RMSE: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Metrics for  LinearRegression()
# Trian Accuracy:  0.9642070735955921
# Test Accuracy:  0.9681448878466101
# RMSE:  0.07034712944382307
# Metrics for  RandomForestRegressor()
# Trian Accuracy:  0.9999986929912293
# Test Accuracy:  0.999970160384334
# RMSE:  0.0021530465709459507
# Metrics for  KNeighborsRegressor()
# Trian Accuracy:  0.9767327945846743
# Test Accuracy:  0.9637461364211747
# RMSE:  0.07504710771287842
# Metrics for  Lasso()
# Trian Accuracy:  0.0
# Test Accuracy:  -3.1428957524726187e-05
# RMSE:  0.3941519103963027
# Metrics for  Ridge()
# Trian Accuracy:  0.9642070638418112
# Test Accuracy:  0.9681443769705862
# RMSE:  0.07034769353723319
# Metrics for  SVR()
# Trian Accuracy:  0.989633673442705
# Test Accuracy:  0.9884198884377253
# RMSE:  0.04241438585480286

# %% [markdown]
# #### Cross Validation check

# %%
for m in models:
    print("Cross Validation score for ",m, cross_val_score(m,X_sc,y,cv=5).mean())
# Out:
# Cross Validation score for  LinearRegression() 0.9262525222254316
# Cross Validation score for  RandomForestRegressor() 0.9999571779955858
# Cross Validation score for  KNeighborsRegressor() 0.8341248228497898
# Cross Validation score for  Lasso() -1.2004309324076277
# Cross Validation score for  Ridge() 0.9262730111279647
# Cross Validation score for  SVR() 0.9688851400037457

# %% [markdown]
# ##### Based on RMSE score and the Cross validation score RandomForestregressor works fine for our dataset.

# %% [markdown]
# ### Final model - RandomForetRegressor

# %% [markdown]
# ##### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'max_features':["auto", "sqrt", "log2"],'n_estimators':[100,130]}
grd_srch=GridSearchCV(RandomForestRegressor(),param_grid=param)
grd_srch.fit(X_train,y_train)
print(grd_srch.best_estimator_)
print(grd_srch.best_score_)
# Out:
# RandomForestRegressor(n_estimators=130)
# 0.9999901811223075

# %%
m_acc=0
b_rs=0
for i in range(1,20):
    model=RandomForestRegressor(n_estimators=130,random_state=i)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    acc=r2_score(y_test,y_pred)
    if(acc>m_acc):
        m_acc=acc
        b_rs=i
print("Best Accuracy: ",model,"Best RS: ",b_rs)
model=RandomForestRegressor(n_estimators=130,random_state=b_rs)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print("Metrics for ",model)
print("Trian Accuracy: ",model.score(X_train,y_train))
print("Test Accuracy: ",r2_score(y_test,y_pred))
print("RMSE: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Best Accuracy:  RandomForestRegressor(n_estimators=130, random_state=19) Best RS:  8
# Metrics for  RandomForestRegressor(n_estimators=130, random_state=8)
# Trian Accuracy:  0.9999989990084581
# Test Accuracy:  0.9999712765951637
# RMSE:  0.002112393249373839

# %% [markdown]
# ##### We able to build a final regression(average price prediction model) with 99.9% of accuracy and 0.002 RMSE score.

# %% [markdown]
# ### Saving the model - Regression model

# %%
import pickle

# %%
pickle.dump(model,open('C:/Users/yn/Desktop/Yuvi/DataTrained/Saved Models - Evaluation Projects/Avocado Project_reg.pkl','wb'))

# %%
final_model_reg=pickle.load(open('C:/Users/yn/Desktop/Yuvi/DataTrained/Saved Models - Evaluation Projects/Avocado Project_reg.pkl','rb'))

# %%
prediction=final_model_reg.predict(X_test)
result_table=pd.DataFrame({'Actual':y_test,'Predicted':prediction})
result_table
# Out:
#        Actual  Predicted
# 15384    1.99       1.99
# 14212    1.46       1.46
# 14003    1.55       1.55
# 11318    2.01       2.01
# 6219     1.00       1.00
# ...       ...        ...
# 257      1.23       1.23
# 4385     1.08       1.08
# 4789     1.29       1.29
# 1666     1.18       1.18
# 15658    2.08       2.08
#
# [4446 rows x 2 columns]

# %% [markdown]
# ### Predicting Region - Classification problem

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# ##### Checking correlation with target variable

# %%
plt.figure(figsize=(12,8))
df.corr()['region'].sort_values().drop(['region']).plot(kind='bar')
plt.xlabel('Feature variables')
plt.ylabel('Region')
plt.xticks(rotation=90)
plt.title('Correlation between features and AveragePrice')
plt.show()

# %% [markdown]
# From the above plot we can see that the features type,month,year and date are not correlated with target variable Region.
# So let's drop these features

# %%
new_df_clf=new_df.drop(['date','month','year','type'],axis=1)

# %%
new_df_clf.shape
# Out:
# (17782, 10)

# %% [markdown]
# ##### Removing outliers

# %%
for col in new_df_clf.columns:
    sns.boxplot(new_df_clf[col])
    plt.show()

# %%
ouliers_features_clf=['AveragePrice','XLarge Bags','Total Bags']

# %%
score=zscore(new_df_clf[ouliers_features_clf])
filters=(score<3).all(axis=1)
new_df_clf=new_df_clf[filters]
print(new_df_clf.shape)
# Out:
# (17659, 10)

# %%
X=new_df_clf.drop(['region'],axis=1)
y=new_df_clf['region']

# %% [markdown]
# ##### Checking data skewness

# %%
X.skew().sort_values()
# Out:
# XLarge Bags    -0.288439
# Large Bags     -0.115643
# 4225           -0.052488
# 4046           -0.047869
# Small Bags     -0.029684
# Total Bags     -0.019962
# Total Volume   -0.017286
# 4770            0.018167
# AveragePrice    0.384773
# dtype: float64

# %% [markdown]
# We do not have any skweness in the data. Lets proceed building model.

# %%
X_sc=StandardScaler().fit_transform(X)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,plot_roc_curve,roc_auc_score

# %% [markdown]
# ##### Finding best Random state

# %%
m_acc=0
b_rs=0
for i in range(1,100):
    lr=KNeighborsClassifier()
    X_train,X_test,y_train,y_test=train_test_split(X_sc,y,test_size=0.25,random_state=i)
    lr.fit(X_train,y_train)
    y_pred=lr.predict(X_test)
    acc=r2_score(y_test,y_pred)
    if(acc>m_acc):
        m_acc=acc
        b_rs=i
print("Best Accuracy: ",m_acc,"Best RS: ",b_rs)
# Out:
# Best Accuracy:  0.708397256339088 Best RS:  87

# %% [markdown]
# ##### spliting the train test data using best random state dound

# %%
X_train,X_test,y_train,y_test=train_test_split(X_sc,y,test_size=0.25,random_state=87)

# %%
rf_clf=RandomForestClassifier()
gb_clf=GradientBoostingClassifier()
knn_clf=KNeighborsClassifier()
svm_clf=SVC()
dt_clf=DecisionTreeClassifier()

models=[rf_clf,knn_clf,svm_clf,dt_clf,gb_clf]

# %% [markdown]
# ### Building base models - model selection

# %%
for m in models:
    m.fit(X_train,y_train)
    y_pred=m.predict(X_test)
    print("Metrics for ",m)
    print("Trian Accuracy: ",m.score(X_train,y_train))
    print("Test Accuracy: ",accuracy_score(y_test,y_pred))
    print("Confusion Matrix:\n ",confusion_matrix(y_test,y_pred))
    print('Classification report:\n',classification_report(y_test,y_pred))
# Out:
# Metrics for  RandomForestClassifier()
# Trian Accuracy:  1.0
# Test Accuracy:  0.8853907134767837
# Confusion Matrix:
#   [[80  0  0 ...  0  0  0]
#  [ 0 73  0 ...  0  0  0]
#  [ 0  0 90 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 42  0  0]
#  [ 0  0  0 ...  0 62  0]
#  [ 0  1  0 ...  0  0 54]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90        89
#            1       0.88      0.79      0.83        92
#            2       0.95      0.99      0.97        91
#            3       0.90      0.80      0.85        83
#            4       0.92      0.89      0.91        93
#            5       0.82      0.85      0.84        87
#            6       0.94      0.99      0.96        76
#            7       0.95      0.91      0.93        81
#            8       0.98      0.99      0.98        84
#            9       0.91      0.82      0.86        95
#           10       0.87      0.84      0.85        93
# ...

# %% [markdown]
# #### Cross Validation Check

# %%
for m in models:
    print("Cross Validation score for ",m, cross_val_score(m,X_sc,y,cv=5).mean())
# Out:
# Cross Validation score for  RandomForestClassifier() 0.6517818397349732
# Cross Validation score for  KNeighborsClassifier() 0.5749930802184695
# Cross Validation score for  SVC() 0.5862622371084389
# Cross Validation score for  DecisionTreeClassifier() 0.5339978889454445
# Cross Validation score for  GradientBoostingClassifier() 0.5885270503320694

# %% [markdown]
# ##### Based on base model score and cross validation score, RandomForest Classifier performs well for our dataset.

# %% [markdown]
# ### Final Model - RandomForestClassifier

# %% [markdown]
# ##### Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'criterion':['gini','entropy'],'n_estimators':[100,150],
       'max_features':["auto", "sqrt", "log2"]}
grd_srch=GridSearchCV(RandomForestClassifier(),param_grid=param,n_jobs=-1)
grd_srch.fit(X_train,y_train)
print(grd_srch.best_estimator_)
print(grd_srch.best_score_)
# Out:
# RandomForestClassifier(criterion='entropy', max_features='log2',
#                        n_estimators=150)
# 0.878208729509739

# %% [markdown]
# #### Finding best Random state

# %%
m_acc=0
b_rs=0
for i in range(1,10):
    model=RandomForestClassifier(n_jobs=-1,criterion='entropy',max_features='log2', n_estimators=150,random_state=i)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    acc=r2_score(y_test,y_pred)
    if(acc>m_acc):
        m_acc=acc
        b_rs=i
print("Best Accuracy: ",m_acc,"Best RS: ",b_rs)
model=RandomForestClassifier(n_jobs=-1,criterion='entropy',max_features='log2',n_estimators=150,random_state=b_rs)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print("Metrics for ",model)
print("Trian Accuracy: ",model.score(X_train,y_train))
print("Test Accuracy: ",accuracy_score(y_test,y_pred))
print("Confusion Matrix:\n ",confusion_matrix(y_test,y_pred))
print('Classification report:\n',classification_report(y_test,y_pred))
# Out:
# Best Accuracy:  0.7919378763999436 Best RS:  7
# Metrics for  RandomForestClassifier(criterion='entropy', max_features='log2',
#                        n_estimators=150, n_jobs=-1, random_state=7)
# Trian Accuracy:  1.0
# Test Accuracy:  0.886070215175538
# Confusion Matrix:
#   [[82  0  0 ...  0  0  0]
#  [ 0 76  0 ...  0  0  0]
#  [ 0  0 90 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 42  0  0]
#  [ 0  0  0 ...  0 62  0]
#  [ 0  0  0 ...  0  0 55]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91        89
#            1       0.86      0.83      0.84        92
#            2       0.92      0.99      0.95        91
#            3       0.93      0.77      0.84        83
#            4       0.93      0.87      0.90        93
#            5       0.83      0.89      0.86        87
#            6       0.95      0.99      0.97        76
#            7       0.95      0.90      0.92        81
# ...

# %% [markdown]
# ##### We able to build a classification model with 89% of accuracy.

# %% [markdown]
# ### Saving the model

# %%
pickle.dump(model,open('C:/Users/yn/Desktop/Yuvi/DataTrained/Saved Models - Evaluation Projects/Avocado Project_clf.pkl','wb'))

# %%
final_model_clf=pickle.load(open('C:/Users/yn/Desktop/Yuvi/DataTrained/Saved Models - Evaluation Projects/Avocado Project_clf.pkl','rb'))

# %%
prediction=final_model_clf.predict(X_test)
result_table=pd.DataFrame({'Actual':y_test,'Predicted':prediction})
result_table
# Out:
#        Actual  Predicted
# 10142      19         19
# 15387      12         12
# 7452       34         34
# 379         7          7
# 17326      48         48
# ...       ...        ...
# 2425       46         46
# 17560      53         53
# 12550      11         11
# 4591       34         34
# 4298       28         28
#
# [4446 rows x 2 columns]
